# %%
import pandas as pd
d = pd.read_csv("Symptom.csv")

# %%
d.head()
# Out:
#     id  user_id  acne  backache  bloating  cramp  diarrhea  dizzy  headache  \
# 0  127      252     0         0         0      0         0      0         0
# 1  128      257     0         0         0     46         0      0         0
# 2  129      257     0         0         0      0         0     27        48
# 3  130      263     0         0         0      0         0      0         0
# 4  132      269     0         0         0      0         0      0         0
#
#    mood  nausea  sore     date
# 0     0       0     0  11/4/15
# 1     0       0     0  10/4/15
# 2     0       0     0  11/4/15
# 3     0       0     0  11/4/15
# 4     0       0     0  11/4/15

# %%
d.dropna()
# Out:
#           id  user_id  acne  backache  bloating  cramp  diarrhea  dizzy  \
# 0        127      252     0         0         0      0         0      0
# 1        128      257     0         0         0     46         0      0
# 2        129      257     0         0         0      0         0     27
# 3        130      263     0         0         0      0         0      0
# 4        132      269     0         0         0      0         0      0
# 5        133      270     0         0         0      0         0      0
# 6        134      271     0         0        15     22         0      0
# 7        135      254     0         0         0      0         0      0
# 8        136      273     0         0         0     20         0      0
# 9        137      275     0         0         0      0         0      0
# 10       138      262    71         0        45      0         0      0
# 11       139      257     0         0         0      0         0      0
# ...

# %%
import matplotlib.pyplot as plt
d1 = d.iloc[14:45,:]
plt.scatter(d1['cramp'],d1['acne'])
plt.plot(d1['cramp'],d1['acne'])

# %%
plt.plot(d1['acne'],d1['backache'])

# %%
plt.plot(d1['cramp'],d1['bloating'])

# %%
plt.plot(d1["diarrhea"],d1["mood"])
